# %%
import pandas as pd

# %%
df1 = pd.read_csv('../data/processed/amazon_books_p.csv')
df2 = pd.read_csv('../data/processed/openlibrary_books_p.csv')

# %%
df1.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0826414346                           Dr. Seuss: American Icon
# 1  0595344550                      Whispers of the Wicked Saints
# 2  0802841899  The Church of Christ: A Biblical Ecclesiology ...
# 3  0895554224                           Saint Hyacinth of Poland
# 4  0854968350  Muslim Women's Choices: Religious Belief and S...
#
#                                 Book-Author  Year-Of-Publication  \
# 0                            ['Philip Nel']               2005.0
# 1                       ['Veronica Haddon']               2005.0
# 2                      ['Everett Ferguson']               1996.0
# 3                  ['Mary Fabyan Windeatt']               2009.0
# 4  ['Camillia Fawzi El-Solh', 'Judy Mabro']               1994.0
#
#                     Publisher  \
# 0                   A&C Black
# 1                   iUniverse
# 2  Wm. B. Eerdmans Publishing
# 3             Tan Books & Pub
# ...

# %%
df2.head()
# Out:
#          ISBN                                    Book-Title  \
# 0  0316109215  Arthur's New Puppy (Arthur Adventure Series)
# 1  7513305943                 Ge zi xiang yao xiao gou gou!
# 2  0525463631                                         Puppy
# 3  1471144607                       Dork Diaries Puppy Love
# 4  141694737X                                      Dear Zoo
#
#             Book-Author  Year-Of-Publication                    Publisher  \
# 0            Marc Brown               1995.0  Little, Brown Young Readers
# 1            Mo Willems               2012.0       Xin xing chu ban she =
# 2        Discovery Kids               2000.0      Dutton Children's Books
# 3  Rachel Renée Russell               2016.0             Simon & Schuster
# 4          Rod Campbell               2007.0                 Little Simon
#
#                                          Description Categories  \
# 0  Arthur is overjoyed when he brings home his ne...   Puppies
# ...

# %%
df = pd.concat([df1 , df2] , axis=0).reset_index(drop=True)

# %%
df
# Out:
#             ISBN                                         Book-Title  \
# 0     0826414346                           Dr. Seuss: American Icon
# 1     0595344550                      Whispers of the Wicked Saints
# 2     0802841899  The Church of Christ: A Biblical Ecclesiology ...
# 3     0895554224                           Saint Hyacinth of Poland
# 4     0854968350  Muslim Women's Choices: Religious Belief and S...
# ...          ...                                                ...
# 6042  0385680910                            Smarter, faster, better
# 6043  067168339X                                    Esmond in India
# 6044  0545504929  Captain Underpants and the sensational saga of...
# 6045  0689116152                                   A taste of India
# 6046  9385827405                                     Medical Medium
#
#                                    Book-Author  Year-Of-Publication  \
# 0                               ['Philip Nel']               2005.0
# ...

# %%
df.to_csv('../data/processed/current_books.csv',index=False)
