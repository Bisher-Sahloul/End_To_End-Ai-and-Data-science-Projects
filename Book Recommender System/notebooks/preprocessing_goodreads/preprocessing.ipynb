# %%
import pandas as pd

# %%
df = pd.read_csv('../../data/raw/Goodreads/Books.csv')
# Out:
# C:\Users\BS\AppData\Local\Temp\ipykernel_19092\1670041262.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../../data/raw/Goodreads/Books.csv')

# %%
df.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
df.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            2
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            0
# Year-Of-Publication    0
# Publisher              0
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            0
# dtype: int64

# %%
df.rename(columns={"Image-URL-M" : "Image"},inplace=True)
df['Description'] = None	
df['Categories'] = None

# %%
df = df[['ISBN','Book-Title','Book-Author','Year-Of-Publication','Publisher','Description','Categories','Image']]
df.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#   Description Categories                                              Image
# ...

# %%
df["ISBN"].value_counts().unique()
# Out:
# array([1], dtype=int64)

# %%
df['Book-Title'].value_counts()
# Out:
# Book-Title
# Selected Poems                                                                                                                    27
# Little Women                                                                                                                      24
# Wuthering Heights                                                                                                                 21
# Dracula                                                                                                                           20
# The Secret Garden                                                                                                                 20
#                                                                                                                                   ..
# On a Clear Day You Can See General Motors: John Z. De Lorean's Look Inside the Automotive Giant                                    1
# ...

# %%
df['Book-Author'].value_counts()
# Out:
# Book-Author
# Agatha Christie         632
# William Shakespeare     567
# Stephen King            524
# Ann M. Martin           423
# Carolyn Keene           373
#                        ...
# R. Gelman                 1
# Ellery R. Sheets          1
# Artiste C. Arthur         1
# Emily Pearl Kingsley      1
# Christopher  Biffle       1
# Name: count, Length: 102019, dtype: int64

# %%
df['Year-Of-Publication'].value_counts()
# Out:
# Year-Of-Publication
# 2002    13902
# 2001    13714
# 1999    13413
# 2000    13373
# 1998    12116
#         ...
# 2021        1
# 1924        1
# 2012        1
# 1927        1
# 2037        1
# Name: count, Length: 200, dtype: int64

# %%
df['Publisher'].value_counts()
# Out:
# Publisher
# Harlequin                        7535
# Silhouette                       4220
# Pocket                           3905
# Ballantine Books                 3783
# Bantam Books                     3646
#                                  ...
# Windstream Publishing Company       1
# Polaris Books                       1
# Hannover House                      1
# Amber Quill Press, LLC.             1
# Connaught                           1
# Name: count, Length: 16803, dtype: int64
