# %%
import pandas as pd

# %%
df1 = pd.read_csv('../data/processed/current_books.csv')
df2 = pd.read_csv('../data/processed/amazon_reviews_p.csv')

# %%
df = df2.merge(df1 , how='inner' , on = 'ISBN')[['ISBN','User_id' , 'rating' , 'review']]
df
# Out:
#              ISBN         User_id  rating  \
# 0      015201294X  A2L8RR2B6HO24F     4.0
# 1      015201294X   A3U3RS1HYT8BK     5.0
# 2      015201294X   AJ9RZKCNVA7DK     5.0
# 3      015201294X   AAYH3NGH1TCUT     5.0
# 4      015201294X  A20A1RL7J10Y1Y     5.0
# ...           ...             ...     ...
# 84559  B000K5SI5O  A1A1I147PQIHWE     4.0
# 84560  B000K5SI5O  A2PASDJQR83CTV     4.0
# 84561  B000K5SI5O   AHD101501WCN1     5.0
# 84562  9626343400   A5SK63JS3X0VU     5.0
# 84563  9626343400   A13KAPH4WMMSY     5.0
#
#                                                   review
# 0      Hello! In am reading this story for a 6th grad...
# 1      Okay, we can forgive Mrs.Rinaldi for giving Em...
# 2      This is one of my favorite books by Anne Rinal...
# 3      You've heard about the body snatching. Gross r...
# 4      It's the end of Civil War, 1865 in Washington ...
# ...                                                  ...
# ...

# %%
df.to_csv('../data/processed/current_reviews.csv' , index = False)
